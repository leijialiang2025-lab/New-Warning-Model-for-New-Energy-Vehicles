# %%
import pandas as pd
file = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_01.csv"
data = pd.read_csv(file, encoding="GB2312")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148923 entries, 0 to 148922
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   数据采集时间       148923 non-null  object
#  1   车辆状态         148923 non-null  int64
#  2   充电状态         148923 non-null  int64
#  3   车速           148923 non-null  float64
#  4   累计里程         148923 non-null  float64
#  5   总电压          148923 non-null  float64
#  6   总电流          148923 non-null  float64
#  7   SOC          148923 non-null  int64
#  8   DC-DC状态      148923 non-null  int64
#  9   绝缘电阻         148923 non-null  int64
#  10  驱动电机控制器温度    133365 non-null  object
#  11  驱动电机转速       133365 non-null  object
#  12  驱动电机转矩       133365 non-null  object
#  13  驱动电机温度       133365 non-null  object
#  14  电机控制器输入电压    133365 non-null  object
#  15  电机控制器直流母线电流  133365 non-null  object
#  16  电池单体电压最高值    148923 non-null  float64
#  17  电池单体电压最低值    148923 non-null  float64
#  18  最高温度值        148923 non-null  int64
#  19  最低温度值        148923 non-null  int64
#  20  最高报警等级       148923 non-null  int64
# dtypes: float64(6), int64(8), object(7)
# memory usage: 23.9+ MB

# %%
import chardet
# 读取文件的一部分来检测编码
with open(file, 'rb') as f:
    result = chardet.detect(f.read(10000))
print(result)
# Out:
# {'encoding': 'GB2312', 'confidence': 0.99, 'language': 'Chinese'}

# %%
pd.set_option('display.max_columns', None)
data.head(10)
# Out:
#           数据采集时间  车辆状态  充电状态    车速      累计里程    总电压    总电流  SOC  DC-DC状态  \
# 0  2022/1/1 0:00     1     3  69.1  129850.3  355.1   11.7   50        1
# 1  2022/1/1 0:00     1     3  81.3  129850.5  346.7  237.1   50        1
# 2  2022/1/1 0:00     1     3  75.6  129850.7  354.7    9.9   50        1
# 3  2022/1/1 0:00     1     3  54.4  129850.9  358.5 -122.2   50        1
# 4  2022/1/1 0:00     1     3  26.9  129851.0  353.3   69.1   50        1
# 5  2022/1/1 0:00     1     3  61.1  129851.1  353.4   31.0   50        1
# 6  2022/1/1 0:01     1     3  65.6  129851.3  354.7   19.9   50        1
# 7  2022/1/1 0:01     1     3  58.6  129851.4  355.4    5.0   50        1
# 8  2022/1/1 0:01     1     3  54.2  129851.6  357.5   20.1   50        1
# 9  2022/1/1 0:01     1     3  57.2  129851.7  353.4   40.2   49        1
#
#    绝缘电阻 驱动电机控制器温度   驱动电机转速     驱动电机转矩 驱动电机温度 电机控制器输入电压  \
# 0  5338      1:21   1:3956      1:7.3   1:32   1:355.0
# 1  5131      1:57   1:4615    1:156.9   1:32   1:342.0
# 2  5404      1:21   1:4299      1:5.5   1:33   1:355.0
# 3  5453      1:34   1:3062   1:-149.4   1:33   1:363.0
# 4  5258      1:42   1:1557    1:130.9   1:34   1:353.0
# 5  5313      1:24   1:3490     1:25.7   1:35   1:354.0
# 6  5345      1:22   1:3741     1:15.2   1:36   1:355.0
# 7  5329      1:22   1:3343      1:2.8   1:35   1:356.0
# 8  5472      1:22   1:3090     1:18.4   1:35   1:355.0
# 9  5401      1:23   1:3256     1:37.5   1:35   1:354.0
#
#               电机控制器直流母线电流  电池单体电压最高值  电池单体电压最低值  最高温度值  最低温度值  最高报警等级
# 0    1:11.100000000000023      3.709      3.688     26     24       0
# 1    1:225.20000000000005      3.630      3.587     26     24       0
# 2     1:9.399999999999977      3.704      3.684     26     24       0
# 3   1:-116.10000000000002      3.746      3.726     26     24       0
# 4     1:65.59999999999991      3.688      3.668     26     24       0
# 5     1:29.40000000000009      3.690      3.670     26     24       0
# 6    1:18.899999999999977      3.704      3.685     26     24       0
# 7    1:4.7000000000000455      3.710      3.692     26     24       0
# 8                  1:19.0      3.735      3.715     26     24       0
# 9     1:38.09999999999991      3.689      3.670     26     24       0

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133365 entries, 0 to 148922
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   数据采集时间       133365 non-null  object
#  1   车辆状态         133365 non-null  int64
#  2   充电状态         133365 non-null  int64
#  3   车速           133365 non-null  float64
#  4   累计里程         133365 non-null  float64
#  5   总电压          133365 non-null  float64
#  6   总电流          133365 non-null  float64
#  7   SOC          133365 non-null  int64
#  8   DC-DC状态      133365 non-null  int64
#  9   绝缘电阻         133365 non-null  int64
#  10  驱动电机控制器温度    133365 non-null  object
#  11  驱动电机转速       133365 non-null  object
#  12  驱动电机转矩       133365 non-null  object
#  13  驱动电机温度       133365 non-null  object
#  14  电机控制器输入电压    133365 non-null  object
#  15  电机控制器直流母线电流  133365 non-null  object
#  16  电池单体电压最高值    133365 non-null  float64
#  17  电池单体电压最低值    133365 non-null  float64
#  18  最高温度值        133365 non-null  int64
#  19  最低温度值        133365 non-null  int64
#  20  最高报警等级       133365 non-null  int64
# dtypes: float64(6), int64(8), object(7)
# memory usage: 22.4+ MB

# %%
data.drop('数据采集时间', axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133365 entries, 0 to 148922
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   车辆状态         133365 non-null  int64
#  1   充电状态         133365 non-null  int64
#  2   车速           133365 non-null  float64
#  3   累计里程         133365 non-null  float64
#  4   总电压          133365 non-null  float64
#  5   总电流          133365 non-null  float64
#  6   SOC          133365 non-null  int64
#  7   DC-DC状态      133365 non-null  int64
#  8   绝缘电阻         133365 non-null  int64
#  9   驱动电机控制器温度    133365 non-null  object
#  10  驱动电机转速       133365 non-null  object
#  11  驱动电机转矩       133365 non-null  object
#  12  驱动电机温度       133365 non-null  object
#  13  电机控制器输入电压    133365 non-null  object
#  14  电机控制器直流母线电流  133365 non-null  object
#  15  电池单体电压最高值    133365 non-null  float64
#  16  电池单体电压最低值    133365 non-null  float64
#  17  最高温度值        133365 non-null  int64
#  18  最低温度值        133365 non-null  int64
#  19  最高报警等级       133365 non-null  int64
# dtypes: float64(6), int64(8), object(6)
# memory usage: 21.4+ MB

# %%
#去掉前缀
data['驱动电机控制器温度'] = data['驱动电机控制器温度'].str.split(':').str[1]
data['驱动电机转速'] = data['驱动电机转速'].str.split(':').str[1]
data['驱动电机转矩'] = data['驱动电机转矩'].str.split(':').str[1]
data['驱动电机温度'] = data['驱动电机温度'].str.split(':').str[1]
data['电机控制器直流母线电流'] = data['电机控制器直流母线电流'].str.split(':').str[1]
data['电机控制器输入电压'] = data['电机控制器输入电压'].str.split(':').str[1]
data.head()
# Out:
#    车辆状态  充电状态    车速      累计里程    总电压    总电流  SOC  DC-DC状态  绝缘电阻 驱动电机控制器温度  \
# 0     1     3  69.1  129850.3  355.1   11.7   50        1  5338        21
# 1     1     3  81.3  129850.5  346.7  237.1   50        1  5131        57
# 2     1     3  75.6  129850.7  354.7    9.9   50        1  5404        21
# 3     1     3  54.4  129850.9  358.5 -122.2   50        1  5453        34
# 4     1     3  26.9  129851.0  353.3   69.1   50        1  5258        42
#
#   驱动电机转速  驱动电机转矩 驱动电机温度 电机控制器输入电压          电机控制器直流母线电流  电池单体电压最高值  电池单体电压最低值  \
# 0   3956     7.3     32     355.0   11.100000000000023      3.709      3.688
# 1   4615   156.9     32     342.0   225.20000000000005      3.630      3.587
# 2   4299     5.5     33     355.0    9.399999999999977      3.704      3.684
# 3   3062  -149.4     33     363.0  -116.10000000000002      3.746      3.726
# 4   1557   130.9     34     353.0    65.59999999999991      3.688      3.668
#
#    最高温度值  最低温度值  最高报警等级
# 0     26     24       0
# 1     26     24       0
# 2     26     24       0
# 3     26     24       0
# 4     26     24       0

# %%
data['驱动电机控制器温度'] = pd.to_numeric(data['驱动电机控制器温度'], errors='coerce')
data['驱动电机转速'] = pd.to_numeric(data['驱动电机转速'], errors='coerce')
data['驱动电机转矩'] = pd.to_numeric(data['驱动电机转矩'], errors='coerce')
data['驱动电机温度'] = pd.to_numeric(data['驱动电机温度'], errors='coerce')
data['电机控制器输入电压'] = pd.to_numeric(data['电机控制器输入电压'], errors='coerce')
data['电机控制器直流母线电流'] = pd.to_numeric(data['电机控制器直流母线电流'], errors='coerce')

# %%
data.describe(include='all').T
# Out:
#                 count           mean          std         min         25%  \
# 车辆状态         133365.0       1.032385     0.177021       1.000       1.000
# 充电状态         133365.0       3.245139     7.742137       3.000       3.000
# 车速           133365.0      24.198258    21.205536       0.000       0.300
# 累计里程         133365.0  134379.973729  2560.377518  129850.300  132180.200
# 总电压          133365.0     372.359968    16.566949     328.100     357.100
# 总电流          133365.0       8.248429    25.296168    -139.200       0.200
# SOC          133365.0      66.420410    20.402277       0.000      51.000
# DC-DC状态      133365.0       1.031073     0.173515       1.000       1.000
# 绝缘电阻         133365.0    6332.167000  6569.288372    1169.000    5300.000
# 驱动电机控制器温度    133365.0      28.336805     6.264026      12.000      25.000
# 驱动电机转速       133365.0    1379.350234  1205.945200    -644.000       8.000
# 驱动电机转矩       133365.0      12.067473    49.711419    -216.800      -2.100
# 驱动电机温度       133365.0      34.501751     5.203787      11.000      32.000
# 电机控制器输入电压    133365.0     360.935298    64.858410       0.000     356.000
# 电机控制器直流母线电流  133365.0       7.634385    24.078444    -132.300       0.000
# 电池单体电压最高值    133365.0       3.889043     0.172794       3.437       3.729
# 电池单体电压最低值    133365.0       3.862938     0.168410       3.406       3.707
# 最高温度值        133365.0      24.454017     2.998001      16.000      23.000
# 最低温度值        133365.0      22.908882     2.916328      15.000      21.000
# 最高报警等级       133365.0       0.012649     0.158530       0.000       0.000
#
#                     50%         75%         max
# 车辆状态              1.000       1.000       2.000
# 充电状态              3.000       3.000     254.000
# 车速               22.700      41.200     327.600
# 累计里程         134376.400  136560.900  138899.200
# 总电压             373.500     386.000     406.300
# 总电流               1.000      17.900     338.400
# SOC              69.000      83.000     100.000
# DC-DC状态           1.000       1.000       2.000
# 绝缘电阻           5343.000    5390.000   50000.000
# 驱动电机控制器温度        28.000      31.000     104.000
# 驱动电机转速         1298.000    2352.000    6571.000
# 驱动电机转矩            0.000      31.000     340.000
# 驱动电机温度           35.000      38.000      53.000
# 电机控制器输入电压       372.000     385.000     406.000
# 电机控制器直流母线电流       0.700      17.000     321.400
# 电池单体电压最高值         3.902       4.030       4.240
# 电池单体电压最低值         3.872       4.002       4.213
# 最高温度值            25.000      26.000      39.000
# 最低温度值            23.000      25.000      37.000
# 最高报警等级            0.000       0.000       2.000

# %%
unique_values = set(data['充电状态'])
unique_values
# Out:
# {3, 4, 254}
