# %%
import pandas as pd
file1 = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_01.csv"
data1 = pd.read_csv(file, encoding="GB2312")
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148923 entries, 0 to 148922
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   数据采集时间       148923 non-null  object
#  1   车辆状态         148923 non-null  int64
#  2   充电状态         148923 non-null  int64
#  3   车速           148923 non-null  float64
#  4   累计里程         148923 non-null  float64
#  5   总电压          148923 non-null  float64
#  6   总电流          148923 non-null  float64
#  7   SOC          148923 non-null  int64
#  8   DC-DC状态      148923 non-null  int64
#  9   绝缘电阻         148923 non-null  int64
#  10  驱动电机控制器温度    133365 non-null  object
#  11  驱动电机转速       133365 non-null  object
#  12  驱动电机转矩       133365 non-null  object
#  13  驱动电机温度       133365 non-null  object
#  14  电机控制器输入电压    133365 non-null  object
#  15  电机控制器直流母线电流  133365 non-null  object
#  16  电池单体电压最高值    148923 non-null  float64
#  17  电池单体电压最低值    148923 non-null  float64
# ...

# %%
data1 = data1.drop(columns='数据采集时间')

# %%
data1['月份'] = 1

# %%
data1.to_csv('month1', index = False)

# %%
file2 = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_02.csv"
data2 = pd.read_csv(file2, encoding="GB2312")
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144826 entries, 0 to 144825
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   数据采集时间       144826 non-null  object
#  1   车辆状态         144826 non-null  int64
#  2   充电状态         144826 non-null  int64
#  3   车速           144826 non-null  float64
#  4   累计里程         144826 non-null  float64
#  5   总电压          144826 non-null  float64
#  6   总电流          144826 non-null  float64
#  7   SOC          144826 non-null  int64
#  8   DC-DC状态      144826 non-null  int64
#  9   绝缘电阻         144826 non-null  int64
#  10  驱动电机控制器温度    125210 non-null  object
#  11  驱动电机转速       125210 non-null  object
#  12  驱动电机转矩       125210 non-null  object
#  13  驱动电机温度       125210 non-null  object
#  14  电机控制器输入电压    125210 non-null  object
#  15  电机控制器直流母线电流  125210 non-null  object
#  16  电池单体电压最高值    144826 non-null  float64
#  17  电池单体电压最低值    144826 non-null  float64
# ...

# %%
pd.set_option('display.max_columns', None)
data2.head(10)
# Out:
#           数据采集时间  车辆状态  充电状态    车速      累计里程    总电压   总电流  SOC  DC-DC状态  绝缘电阻  \
# 0  2022/2/1 0:00     1     3  52.3  138899.4  347.4 -32.9   26        1  5239
# 1  2022/2/1 0:00     1     3  50.5  138899.5  345.4  10.7   26        1  5234
# 2  2022/2/1 0:00     1     3  48.3  138899.7  345.1  14.6   26        1  5197
# 3  2022/2/1 0:00     1     3  51.2  138899.8  344.7  11.8   26        1  5280
# 4  2022/2/1 0:00     1     3  48.3  138899.9  346.4 -31.8   26        1  5343
# 5  2022/2/1 0:00     1     3  49.8  138900.1  344.4  23.5   26        1  5438
# 6  2022/2/1 0:01     1     3  51.3  138900.2  345.0  12.7   26        1  5457
# 7  2022/2/1 0:01     1     3  52.4  138900.4  345.0  11.6   26        1  5334
# 8  2022/2/1 0:01     1     3  48.2  138900.5  345.4   4.4   26        1  5334
# 9  2022/2/1 0:01     1     3  45.5  138900.6  345.8 -20.8   26        1  5411
#
#   驱动电机控制器温度   驱动电机转速    驱动电机转矩 驱动电机温度 电机控制器输入电压             电机控制器直流母线电流  \
# ...

# %%
data2 = data2.drop(columns='数据采集时间')
data2['月份'] = 2
data2.to_csv('month2', index = False)

# %%
file3 = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_03.csv"
data3 = pd.read_csv(file3, encoding="GB2312")
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164773 entries, 0 to 164772
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   数据采集时间       164773 non-null  object
#  1   车辆状态         164773 non-null  int64
#  2   充电状态         164773 non-null  int64
#  3   车速           164773 non-null  float64
#  4   累计里程         164773 non-null  float64
#  5   总电压          164773 non-null  float64
#  6   总电流          164773 non-null  float64
#  7   SOC          164773 non-null  int64
#  8   DC-DC状态      164773 non-null  int64
#  9   绝缘电阻         164773 non-null  int64
#  10  驱动电机控制器温度    149189 non-null  object
#  11  驱动电机转速       149189 non-null  object
#  12  驱动电机转矩       149189 non-null  object
#  13  驱动电机温度       149189 non-null  object
#  14  电机控制器输入电压    149189 non-null  object
#  15  电机控制器直流母线电流  149189 non-null  object
#  16  电池单体电压最高值    164773 non-null  float64
#  17  电池单体电压最低值    164773 non-null  float64
# ...

# %%
data3.head(10)
# Out:
#           数据采集时间  车辆状态  充电状态    车速      累计里程    总电压   总电流  SOC  DC-DC状态  绝缘电阻  \
# 0  2022/3/1 0:00     1     3  49.6  147570.7  349.1   8.9   34        1  5311
# 1  2022/3/1 0:00     1     3  39.9  147570.9  352.1 -97.1   34        1  5385
# 2  2022/3/1 0:00     1     3  31.5  147570.9  348.7  16.9   34        1  5245
# 3  2022/3/1 0:00     1     3  32.9  147571.0  348.7   0.5   34        1  5252
# 4  2022/3/1 0:00     1     3  21.6  147571.1  349.7  35.8   34        1  5357
# 5  2022/3/1 0:00     1     3   0.0  147571.1  349.5   0.5   34        1  5343
# 6  2022/3/1 0:01     1     3   0.0  147571.1  349.5   0.5   34        1  5354
# 7  2022/3/1 0:01     1     3   0.9  147571.1  349.5   4.4   34        1  5366
# 8  2022/3/1 0:01     1     3  19.1  147571.2  349.3  -5.7   34        1  5331
# 9  2022/3/1 0:01     1     3  22.2  147571.2  349.4   8.0   34        1  5329
#
#   驱动电机控制器温度   驱动电机转速     驱动电机转矩 驱动电机温度 电机控制器输入电压             电机控制器直流母线电流  \
# ...

# %%
data3 = data3.drop(columns='数据采集时间')
data3['月份'] = 3
data3.to_csv('month3', index = False)

# %%
file4 = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_04.csv"
data4 = pd.read_csv(file4, encoding="GB2312")
data4.info()
data4.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77415 entries, 0 to 77414
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   数据采集时间       77415 non-null  object
#  1   车辆状态         77415 non-null  int64
#  2   充电状态         77415 non-null  int64
#  3   车速           77415 non-null  float64
#  4   累计里程         77415 non-null  float64
#  5   总电压          77415 non-null  float64
#  6   总电流          77415 non-null  float64
#  7   SOC          77415 non-null  int64
#  8   DC-DC状态      77415 non-null  int64
#  9   绝缘电阻         77415 non-null  int64
#  10  驱动电机控制器温度    69945 non-null  object
#  11  驱动电机转速       69945 non-null  object
#  12  驱动电机转矩       69945 non-null  object
#  13  驱动电机温度       69945 non-null  object
#  14  电机控制器输入电压    69945 non-null  object
#  15  电机控制器直流母线电流  69945 non-null  object
#  16  电池单体电压最高值    77415 non-null  float64
#  17  电池单体电压最低值    77415 non-null  float64
# ...

# %%
data4 = data4.drop(columns='数据采集时间')
data4['月份'] = 4
data4.to_csv('month4', index = False)

# %%
file5 = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_05.csv"
data5 = pd.read_csv(file5, encoding="GB2312")
data5.info()
data5.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167568 entries, 0 to 167567
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   数据采集时间       167568 non-null  object
#  1   车辆状态         167568 non-null  int64
#  2   充电状态         167568 non-null  int64
#  3   车速           167568 non-null  float64
#  4   累计里程         167568 non-null  float64
#  5   总电压          167568 non-null  float64
#  6   总电流          167568 non-null  float64
#  7   SOC          167568 non-null  int64
#  8   DC-DC状态      167568 non-null  int64
#  9   绝缘电阻         167568 non-null  int64
#  10  驱动电机控制器温度    150792 non-null  object
#  11  驱动电机转速       150792 non-null  object
#  12  驱动电机转矩       150792 non-null  object
#  13  驱动电机温度       150792 non-null  object
#  14  电机控制器输入电压    150792 non-null  object
#  15  电机控制器直流母线电流  150792 non-null  object
#  16  电池单体电压最高值    167568 non-null  float64
#  17  电池单体电压最低值    167568 non-null  float64
# ...

# %%
data5 = data5.drop(columns='数据采集时间')
data5['月份'] = 5
data5.to_csv('month5', index = False)

# %%
file6 = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_06.csv"
data6 = pd.read_csv(file6, encoding="GB2312")
data6.info()
data6.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154246 entries, 0 to 154245
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   数据采集时间       154246 non-null  object
#  1   车辆状态         154246 non-null  int64
#  2   充电状态         154246 non-null  int64
#  3   车速           154246 non-null  float64
#  4   累计里程         154246 non-null  float64
#  5   总电压          154246 non-null  float64
#  6   总电流          154246 non-null  float64
#  7   SOC          154246 non-null  int64
#  8   DC-DC状态      154246 non-null  int64
#  9   绝缘电阻         154246 non-null  int64
#  10  驱动电机控制器温度    138331 non-null  object
#  11  驱动电机转速       138331 non-null  object
#  12  驱动电机转矩       138331 non-null  object
#  13  驱动电机温度       138331 non-null  object
#  14  电机控制器输入电压    138331 non-null  object
#  15  电机控制器直流母线电流  138331 non-null  object
#  16  电池单体电压最高值    154246 non-null  float64
#  17  电池单体电压最低值    154246 non-null  float64
# ...

# %%
data6 = data6.drop(columns='数据采集时间')
data6['月份'] = 6
data6.to_csv('month6', index = False)

# %%
file7 = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_07.csv"
data7 = pd.read_csv(file7, encoding="GB2312")
data7.info()
data7.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151931 entries, 0 to 151930
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   数据采集时间       151931 non-null  object
#  1   车辆状态         151931 non-null  int64
#  2   充电状态         151931 non-null  int64
#  3   车速           151931 non-null  float64
#  4   累计里程         151931 non-null  float64
#  5   总电压          151931 non-null  float64
#  6   总电流          151931 non-null  float64
#  7   SOC          151931 non-null  int64
#  8   DC-DC状态      151931 non-null  int64
#  9   绝缘电阻         151931 non-null  int64
#  10  驱动电机控制器温度    136541 non-null  object
#  11  驱动电机转速       136541 non-null  object
#  12  驱动电机转矩       136541 non-null  object
#  13  驱动电机温度       136541 non-null  object
#  14  电机控制器输入电压    136541 non-null  object
#  15  电机控制器直流母线电流  136541 non-null  object
#  16  电池单体电压最高值    151931 non-null  float64
#  17  电池单体电压最低值    151931 non-null  float64
# ...

# %%
data7 = data7.drop(columns='数据采集时间')
data7['月份'] = 7
data7.to_csv('month7', index = False)

# %%
file8 = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_08.csv"
data8 = pd.read_csv(file8, encoding="GB2312")
data8.info()
data8.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115479 entries, 0 to 115478
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   数据采集时间       115479 non-null  object
#  1   车辆状态         115479 non-null  int64
#  2   充电状态         115479 non-null  int64
#  3   车速           115479 non-null  float64
#  4   累计里程         115479 non-null  float64
#  5   总电压          115479 non-null  float64
#  6   总电流          115479 non-null  float64
#  7   SOC          115479 non-null  int64
#  8   DC-DC状态      115479 non-null  int64
#  9   绝缘电阻         115479 non-null  int64
#  10  驱动电机控制器温度    102927 non-null  object
#  11  驱动电机转速       102927 non-null  object
#  12  驱动电机转矩       102927 non-null  object
#  13  驱动电机温度       102927 non-null  object
#  14  电机控制器输入电压    102927 non-null  object
#  15  电机控制器直流母线电流  102927 non-null  object
#  16  电池单体电压最高值    115479 non-null  float64
#  17  电池单体电压最低值    115479 non-null  float64
# ...

# %%
data8 = data8.drop(columns='数据采集时间')
data8['月份'] = 8
data8.to_csv('month8', index = False)

# %%
file9 = r"D:\学习\Naraka\加勒比地区数据\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛赛题\2024年第四届高校大数据挑战赛-B赛题\附件\month_09.csv"
data9 = pd.read_csv(file9, encoding="GB2312")
data9.info()
data9.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41045 entries, 0 to 41044
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   数据采集时间       41045 non-null  object
#  1   车辆状态         41045 non-null  int64
#  2   充电状态         41045 non-null  int64
#  3   车速           41045 non-null  float64
#  4   累计里程         41045 non-null  float64
#  5   总电压          41045 non-null  float64
#  6   总电流          41045 non-null  float64
#  7   SOC          41045 non-null  int64
#  8   DC-DC状态      41045 non-null  int64
#  9   绝缘电阻         41045 non-null  int64
#  10  驱动电机控制器温度    36519 non-null  object
#  11  驱动电机转速       36519 non-null  object
#  12  驱动电机转矩       36519 non-null  object
#  13  驱动电机温度       36519 non-null  object
#  14  电机控制器输入电压    36519 non-null  object
#  15  电机控制器直流母线电流  36519 non-null  object
#  16  电池单体电压最高值    41045 non-null  float64
#  17  电池单体电压最低值    41045 non-null  float64
# ...

# %%
data9 = data9.drop(columns='数据采集时间')
data9['月份'] = 9
data9.to_csv('month9', index = False)
